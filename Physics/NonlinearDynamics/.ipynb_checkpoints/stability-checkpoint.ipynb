# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
L=1
plt.rcParams['font.family'] = 'Times New Roman'

# %%
def xdot(x,y):
  #return x*(3-x-2*y)
  return y
def ydot(x,y):
  #return y*(2-x-y)
  return - (9.8 / L)*np.sin(x)

# %%
y, x= np.mgrid[-2:2:20j,-2:2:20j]
strm = plt.streamplot(x,y,xdot(x,y),ydot(x,y),color=np.sqrt(xdot(x,y)**2+ydot(x,y)**2),cmap='plasma')
plt.colorbar(strm.lines)
plt.xlabel("x", fontsize=20, style="italic")
plt.ylabel("y", fontsize=20, style="italic")
plt.savefig("../figures/pendulum2.png")

# %%
x = np.arange(-5,5, 0.01)

y = x**2 -1

fig,ax = plt.subplots(figsize=(4,3),facecolor='white',dpi=150)
ax.plot(x,y)
plt.xlim([-5,5])
plt.ylim([-3,10])
plt.grid()
ax.spines['bottom'].set_position('zero')
ax.spines['left'].set_position('zero')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(direction='inout')
plt.savefig("../figures/fixed.png", dpi=500)

# %%
def xdot(x,y):
  #return x*(3-x-2*y)
  return a*x
def ydot(x,y):
  #return y*(2-x-y)
  return b*y

# %%
plt.figure(figsize = (20,10))
plt.subplot(2,3,1)
a = -1
b = -1
y, x= np.mgrid[-2:2:20j,-2:2:20j]
strm = plt.streamplot(x,y,xdot(x,y),ydot(x,y),color=np.sqrt(xdot(x,y)**2+ydot(x,y)**2),cmap='plasma')
plt.colorbar(strm.lines)
plt.title("(a) a = d < 0", fontsize = 25)

plt.subplot(2,3,2)
a = -2
b = -1
y, x= np.mgrid[-2:2:20j,-2:2:20j]
strm = plt.streamplot(x,y,xdot(x,y),ydot(x,y),color=np.sqrt(xdot(x,y)**2+ydot(x,y)**2),cmap='plasma')
plt.colorbar(strm.lines)
plt.title("(b) a < d < 0", fontsize = 25)

plt.subplot(2,3,3)
a = -1
b =1
y, x= np.mgrid[-2:2:20j,-2:2:20j]
strm = plt.streamplot(x,y,xdot(x,y),ydot(x,y),color=np.sqrt(xdot(x,y)**2+ydot(x,y)**2),cmap='plasma')
plt.colorbar(strm.lines)
plt.title("(c) a < 0 < d", fontsize = 25)

plt.subplot(2,3,4)
a = 0
b = 2
y, x= np.mgrid[-2:2:20j,-2:2:20j]
strm = plt.streamplot(x,y,xdot(x,y),ydot(x,y),color=np.sqrt(xdot(x,y)**2+ydot(x,y)**2),cmap='plasma')
plt.colorbar(strm.lines)
plt.title("(d) a = 0 < d", fontsize = 25)

plt.subplot(2,3,5)
a = 1
b = 2
y, x= np.mgrid[-2:2:20j,-2:2:20j]
strm = plt.streamplot(x,y,xdot(x,y),ydot(x,y),color=np.sqrt(xdot(x,y)**2+ydot(x,y)**2),cmap='plasma')
plt.colorbar(strm.lines)
plt.title("(e) 0 < a < d", fontsize = 25)

plt.savefig("../figures/phase_space.png")

# %%
A = np.array([2,3,4,-1]).reshape(2,2)

np.linalg.eig(A)
# Out:
# (array([ 4.27491722, -3.27491722]),
#  array([[ 0.79681209, -0.49436913],
#         [ 0.60422718,  0.86925207]]))

# %%
x = np.arange(-10,10,0.01)

v_1 = 0.6/0.8 * x
v_2 = 0.87/-0.49 * x

fig,ax = plt.subplots(figsize=(8,8),facecolor='white',dpi=150)

plt.plot(x, v_1, linewidth = 2)
plt.plot(x, v_2, linewidth = 2)
plt.xlim([-5,5])
plt.ylim([-5,5])
plt.grid()
ax.spines['bottom'].set_position('zero')
ax.spines['left'].set_position('zero')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
ax.tick_params(direction='inout')

plt.savefig("../figures/eigen1.png")

# %%
def xdot(x,y):
  #return x*(3-x-2*y)
  return a * x + b * y
def ydot(x,y):
  #return y*(2-x-y)
  return c * x + d * y

# %%
# Center
a = 2
b = 3
c = 4
d = -1

plt.figure(figsize = (5,5))
y, x= np.mgrid[-2:2:20j,-2:2:20j]
strm = plt.streamplot(x,y,xdot(x,y),ydot(x,y),color=np.sqrt(xdot(x,y)**2+ydot(x,y)**2),cmap='plasma', linewidth=2, arrowsize = 1.5)
#plt.colorbar(strm.lines)
#plt.title("(a) a = d < 0", fontsize = 25)
plt.xticks([])
plt.yticks([])

#plt.savefig("../figures/center.png")
# Out:
# ([], [])

# %%
# Center
a = 0
b = -3
c = 4
d = 0

plt.figure(figsize = (5,5))
y, x= np.mgrid[-2:2:20j,-2:2:20j]
strm = plt.streamplot(x,y,xdot(x,y),ydot(x,y),color=np.sqrt(xdot(x,y)**2+ydot(x,y)**2),cmap='plasma', linewidth=2, arrowsize = 1.5)
#plt.colorbar(strm.lines)
#plt.title("(a) a = d < 0", fontsize = 25)
plt.xticks([])
plt.yticks([])

#plt.savefig("../figures/center.png")
# Out:
# ([], [])

# %%
A = np.array([4,-3,4,-2]).reshape(2,2)
np.linalg.eig(A)
# Out:
# (array([1.+1.73205081j, 1.-1.73205081j]),
#  array([[0.56694671+0.32732684j, 0.56694671-0.32732684j],
#         [0.75592895+0.j        , 0.75592895-0.j        ]]))

# %%
# Unstable spiral
a = 4
b = -3
c = 4
d = -2

plt.figure(figsize = (5,5))
y, x= np.mgrid[-2:2:20j,-2:2:20j]
strm = plt.streamplot(x,y,xdot(x,y),ydot(x,y),color=np.sqrt(xdot(x,y)**2+ydot(x,y)**2),cmap='plasma',linewidth=2, arrowsize = 1.5)
#plt.colorbar(strm.lines)
#plt.title("(a) a = d < 0", fontsize = 25)
plt.xticks([])
plt.yticks([])

plt.savefig("../figures/unstable_spiral.png")

# %%
# Stable spiral
a = -3
b = -4
c = 2
d = 2

plt.figure(figsize = (5,5))
y, x= np.mgrid[-2:2:20j,-2:2:20j]
strm = plt.streamplot(x,y,xdot(x,y),ydot(x,y),color=np.sqrt(xdot(x,y)**2+ydot(x,y)**2),cmap='plasma', linewidth=2, arrowsize = 1.5)
#plt.colorbar(strm.lines)
#plt.title("(a) a = d < 0", fontsize = 25)
plt.xticks([])
plt.yticks([])

plt.savefig("../figures/stable_spiral.png")

# %%
# Unstable node
a = 3
b = 2
c = 1
d = 2

plt.figure(figsize = (5,5))
y, x= np.mgrid[-2:2:20j,-2:2:20j]
strm = plt.streamplot(x,y,xdot(x,y),ydot(x,y),color=np.sqrt(xdot(x,y)**2+ydot(x,y)**2),cmap='plasma', linewidth=2, arrowsize = 1.5)
#plt.colorbar(strm.lines)
#plt.title("(a) a = d < 0", fontsize = 25)
plt.xticks([])
plt.yticks([])

plt.savefig("../figures/unstable_node.png")

# %%
# Unstable node
a = 3
b = 5
c = 0
d = 3

plt.figure(figsize = (5,5))
y, x= np.mgrid[-2:2:20j,-2:2:20j]
strm = plt.streamplot(x,y,xdot(x,y),ydot(x,y),color=np.sqrt(xdot(x,y)**2+ydot(x,y)**2),cmap='plasma', linewidth=2, arrowsize = 1.5)
#plt.colorbar(strm.lines)
#plt.title("(a) a = d < 0", fontsize = 25)
plt.xticks([])
plt.yticks([])

plt.savefig("../figures/degenerate_node.png")

# %%
# Saddle
a = 3
b = -4
c = -4
d = -2

plt.figure(figsize = (5,5))
y, x= np.mgrid[-2:2:20j,-2:2:20j]
strm = plt.streamplot(x,y,xdot(x,y),ydot(x,y),color=np.sqrt(xdot(x,y)**2+ydot(x,y)**2),cmap='plasma', linewidth=2, arrowsize = 1.5)
#plt.colorbar(strm.lines)
#plt.title("(a) a = d < 0", fontsize = 25)
plt.xticks([])
plt.yticks([])

plt.savefig("../figures/saddle.png")

# %%
A = np.array([-3, -4,2,2]).reshape(2,2)
np.linalg.eig(A)
# Out:
# (array([-0.5+1.32287566j, -0.5-1.32287566j]),
#  array([[ 0.81649658+0.j        ,  0.81649658-0.j        ],
#         [-0.51031036-0.27003086j, -0.51031036+0.27003086j]]))

# %%
# Stable line
a = -3
b = -2
c = 3
d = 2

plt.figure(figsize = (5,5))
y, x= np.mgrid[-2:2:20j,-2:2:20j]
strm = plt.streamplot(x,y,xdot(x,y),ydot(x,y),color=np.sqrt(xdot(x,y)**2+ydot(x,y)**2),cmap='plasma', linewidth=2, arrowsize = 1.5)
#plt.colorbar(strm.lines)
#plt.title("(a) a = d < 0", fontsize = 25)
plt.xticks([])
plt.yticks([])

plt.savefig("../figures/stable_line.png")

# %%
# Stable node
a = -3
b = -2
c = -3
d = -5

plt.figure(figsize = (5,5))
y, x= np.mgrid[-2:2:20j,-2:2:20j]
strm = plt.streamplot(x,y,xdot(x,y),ydot(x,y),color=np.sqrt(xdot(x,y)**2+ydot(x,y)**2),cmap='plasma', linewidth=2, arrowsize = 1.5)
#plt.colorbar(strm.lines)
#plt.title("(a) a = d < 0", fontsize = 25)
plt.xticks([])
plt.yticks([])

plt.savefig("../figures/stable_node.png")

# %%
# Stable line
a = -3
b = 0
c = 0
d = -3

plt.figure(figsize = (5,5))
y, x= np.mgrid[-2:2:20j,-2:2:20j]
strm = plt.streamplot(x,y,xdot(x,y),ydot(x,y),color=np.sqrt(xdot(x,y)**2+ydot(x,y)**2),cmap='plasma', linewidth=2, arrowsize = 1.5)
#plt.colorbar(strm.lines)
#plt.title("(a) a = d < 0", fontsize = 25)
plt.xticks([])
plt.yticks([])

plt.savefig("../figures/stable_star.png")

# %%
A = np.array([4, 0, 0, -3]).reshape(2,2)
np.linalg.eig(A)
# Out:
# (array([ 4., -3.]),
#  array([[1., 0.],
#         [0., 1.]]))

# %%
# Stable line
a = 3
b = 2
c = 3
d = 5

plt.figure(figsize = (5,5))
y, x= np.mgrid[-2:2:20j,-2:2:20j]
strm = plt.streamplot(x,y,xdot(x,y),ydot(x,y),color=np.sqrt(xdot(x,y)**2+ydot(x,y)**2),cmap='plasma', linewidth=2, arrowsize = 1.5)
#plt.colorbar(strm.lines)
#plt.title("(a) a = d < 0", fontsize = 25)
plt.xticks([])
plt.yticks([])

#plt.savefig("../figures/stable_node.png")
# Out:
# ([], [])

# %%
# Stable line
a = 3
b = 2
c = 3
d = 2

plt.figure(figsize = (5,5))
y, x= np.mgrid[-2:2:20j,-2:2:20j]
strm = plt.streamplot(x,y,xdot(x,y),ydot(x,y),color=np.sqrt(xdot(x,y)**2+ydot(x,y)**2),cmap='plasma', linewidth=2, arrowsize = 1.5)
#plt.colorbar(strm.lines)
#plt.title("(a) a = d < 0", fontsize = 25)
plt.xticks([])
plt.yticks([])

plt.savefig("../figures/unstable_line.png")

# %% [markdown]
# # 任意の非線形系の相図をプロットする
# xdot, ydotに文字列として，系の方程式を与える．
# 次のセルでは，所与の式から
# - 固定点を求め
# - ヤコビ行列の固有値を各固定点の元で計算し
# - 各固定点の安定性を黒丸(安定)および白丸(不安定)で示し
# - streamplotで他の軌道もplot
# している

# %%
xdot = "y - y**3"
ydot = "-x - y**2"

# %%
# example 1
xdot = "-2*x + 2*x**3"
ydot = "-3*y"

# %%
# example 2
xdot = "-2*y + 2*y**3"
ydot = "-3*x"

# %%
# example 3
xdot = "2*x - x**2 - x*y"
ydot = "3*y - y**2 - x*y"

# %%
# example 4
xdot = "y + y**2"
ydot = "x -x**3"

# %%
import sympy
import numpy as np
import matplotlib.pyplot as plt

x =sympy.Symbol('x')
y = sympy.Symbol('y')

u = eval(xdot)
v = eval(ydot)

# Find fixed points
points = np.array([])
fixed = sympy.solve([u, v])
for i in range(len(fixed)):
    value = np.array([fixed[i][x],fixed[i][y]])
    points = np.append(points, value)

fixed_points = points.reshape(len(points)//2, 2)

# define Jacobian matrix
Jacobian = sympy.Matrix([[u.diff(x), u.diff(y)], [v.diff(x), v.diff(y)]])


plt.figure(figsize = (10,5))

for point in fixed_points:
    # find eigenvalues around each fixed point
    Jacobian_point = Jacobian.subs([(x,point[0]), (y,point[1])])
    eigenvalues = Jacobian_point.eigenvals()
    eigen= list(eigenvalues.keys())
    #if np.all(re(list(eigenvalues.keys())) < 0):
    for i in range(len(eigen)):
    #if ((re(eigen[0]) < 0) and (re(eigen[1]) < 0)) or ((eigen[0] + eigen[1] ==0) and (eigen[0] * eigen[1] >0)): # Stable fixed points or center
        if (re(eigen[i]) < 0): # Stable fixed points or center
            plt.plot(point[0], point[1], 'ko', markersize=10)  # black circle
        else:
            plt.plot(point[0], point[1], 'wo', mec='k', markersize=10, markeredgewidth=2) # Unstable fixed points
    eigen_sum = np.sum(eigen)
    eigen_multipl = np.prod(eigen)
    if (eigen_sum ==0) and (eigen_multipl >0):
        plt.plot(point[0], point[1], 'ko', markersize=10)  # black circle

y, x= np.mgrid[-2:2:20j,-2:2:20j]

# define the system of ODEs
u = eval(xdot)
v = eval(ydot)

# plot the vector field
strm = plt.streamplot(x, y, u, v,color=np.sqrt(u**2+v**2),cmap='plasma', linewidth=2, arrowsize = 1.5)

# plot the nullclines
#plt.contour(x, y, u, levels=[0], linewidths=2, colors='r')
#plt.contour(x, y, v, levels=[0], linewidths=2, colors='b')

plt.title('Phase portrait of the system')
plt.colorbar(strm.lines)
plt.xlabel("x", fontsize=20, style="italic")
plt.ylabel("y", fontsize=20, style="italic")
plt.xlim([-2, 2])
#plt.ylim([-0.5, 0.5])
plt.grid(True)
plt.savefig("../figures/example_phase4.png")

# %%
points
# Out:
# array([-1, -1, -1, 0, 0, -1, 0, 0, 1, -1, 1, 0], dtype=object)

# %%
A = np.array([0, 1, -2, 0]).reshape(2,2)
np.linalg.eig(A)
# Out:
# (array([0.+1.41421356j, 0.-1.41421356j]),
#  array([[0.        -0.57735027j, 0.        +0.57735027j],
#         [0.81649658+0.j        , 0.81649658-0.j        ]]))

# %%
3 + 2*((-1.5)**3)
# Out:
# -3.75
